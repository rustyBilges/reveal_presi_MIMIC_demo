# %%
# %load_ext sql
# %sql mysql://root:mysql2016@localhost/MIMIC
# %sql USE MIMIC
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /usr/local/lib/python2.7/dist-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM D_ITEMS WHERE LABEL LIKE '%urine%'
# Out:
# 156 rows affected.
# [(656, 706, 'Urine [Color]', None, 'carevue', 'chartevents', None, None, None, None, None),
#  (657, 707, 'Urine Source', None, 'carevue', 'chartevents', None, None, None, None, None),
#  (816, 3140, 'Urine Cl-', None, 'carevue', 'chartevents', None, None, None, None, None),
#  (1162, 941, 'urine culture', None, 'carevue', 'chartevents', None, None, None, None, None),
#  (1182, 1011, 'urine osmolarity', None, 'carevue', 'chartevents', None, None, None, None, None),
#  (1361, 1352, 'urine pH', None, 'carevue', 'chartevents', None, None, None, None, None),
#  (1671, 4855, 'Urine culture', None, 'carevue', 'chartevents', None, None, None, None, None),
#  (1913, 5810, 'urine calcium', None, 'carevue', 'chartevents', None, None, None, None, None),
#  (1914, 5811, 'urine creatinine', None, 'carevue', 'chartevents', None, None, None, None, None),
#  (1915, 5812, 'Urine lytes', None, 'carevue', 'chartevents', None, None, None, None, None),
# ...

# %%
#%sql SELECT * FROM D_ITEMS WHERE ITEMID=3420
data=%sql SELECT VALUENUM FROM CHARTEVENTS WHERE ITEMID=3420 AND SUBJECT_ID=8
# Out:
# 8 rows affected.

# %%
clean_data = [row[0] for row in data]

# %%
clean_data
# Out:
# [50.0, 50.0, 30.0, 26.0, 21.0, 21.0, 21.0, None]

# %%
# %%sql
# SELECT VALUENUM
# FROM CHARTEVENTS WHERE ITEMID=3420 AND SUBJECT_ID=8
# Out:
# 8 rows affected.
# [(50.0,), (50.0,), (30.0,), (26.0,), (21.0,), (21.0,), (21.0,), (None,)]
